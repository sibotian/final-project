# %% [markdown]
# ### 1. Setup.

# %%
from scipy import ndimage, misc
from medpy.io import load
from sklearn.model_selection import train_test_split
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import random
import csv
import pickle
import os

# %% [markdown]
# ### 2. Read the images and preprocess.
# #### Save the train and test sets into a pickle file such that we could load it later without run the preprocessing code again.

# %%
def read_img(filepath):
    # Read volume from mha file, and only keep one slice
    image_data, image_header = load(filepath)
    # Only keep the one slice near the middle
    idx = int(image_data.shape[2]/2) + 5
    return image_data[:,:,idx]

def normalize(vol):
    # Threshold between 400 and -1000 is commonly used to normalize CT scans
    max = 400
    min = -1000
    vol[vol > max] = max
    vol[vol < min] = min
    vol = (vol - min) / (max - min)
    vol = vol.astype("float32")
    return vol

def resize(img):
    # Set the desired size
    desired_width = 256
    desired_height = 256
    # Get current size
    current_width = img.shape[0]
    current_height = img.shape[1]
    # Compute size factor
    width = current_width / desired_width
    height = current_height / desired_height
    width_factor = 1 / width
    height_factor = 1 / height
    # Rotate
    img = ndimage.rotate(img, 90, reshape=False)
    # Resize across z-axis
    img = ndimage.zoom(img, (width_factor, height_factor), order=1)
    return img

def process_scan(path):
    # Read CT scan
    volume = read_img(path)
    # Normalize
    volume = normalize(volume)
    # Resize width, height
    volume = resize(volume)
    return volume

# %%
filename = 'C:/Users/ssila/Documents/DL_Project/Dataset/metadata/reference.csv'
fields = []
rows = []
with open(filename, 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for row in csvreader:
        rows.append(row)
print('Field names are:' + ', '.join(field for field in fields))
print('Here is an example: ', rows[0])
# Ids are stored in the train and test list
split=train_test_split(rows, test_size=0.25, shuffle=True)
trainList=split[0]
testList=split[1]
print('Training set size: ',len(trainList))
print('Testing set size: ', len(testList))

# %%
# Get path for both train set and test set
train_path = []
for id in trainList:
    filepath = f'C:/Users/ssila/Documents/DL_Project/Dataset/data/mha/{id[0]}.mha'
    train_path.append(filepath)
test_path = []
for id in testList:
    filepath = f'C:/Users/ssila/Documents/DL_Project/Dataset/data/mha/{id[0]}.mha'
    test_path.append(filepath)
# Load dataset 
print('==========> Begin to load train datasets!')
x_train = np.array([process_scan(path) for path in train_path])
print('==========> Train datasets loaded! Begin to load test datasets!')
x_test = np.array([process_scan(path) for path in test_path])
print('==========> Test datasets loaded!')
print('==========> The size of train and test set are %d and %d.' % (x_train.shape[0], x_test.shape[0]))

# %%
# Load y label
y_train = np.array([int(id[1]) for id in trainList])
y_test = np.array([int(id[1]) for id in testList])
print('Two categories: Non-covid, Covid.')

# %%
# Save the dataset as pkl file since it may take a while to load from mha files
save_path = './'
with open(os.path.join(save_path,"train_DL_2categories.pickle"), "wb") as f:
    pickle.dump((x_train, y_train),f)
with open(os.path.join(save_path,"test_DL_2categories.pickle"), "wb") as f:
    pickle.dump((x_test, y_test),f)

# %%
save_path = './'
with open(os.path.join(save_path, "train_DL_2categories.pickle"), "rb") as f:
    (x_train, y_train) = pickle.load(f)
with open(os.path.join(save_path, "test_DL_2categories.pickle"), "rb") as f:
    (x_test, y_test) = pickle.load(f)
print('Load dataset from pickles, print out the shape of datasets: ')
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Load dataset from pickles, print out the shape of datasets:
# (1500, 256, 256)
# (500, 256, 256)
# (1500,)
# (500,)

# %%
# y_train = to_categorical(y_train)
# y_test = to_categorical(y_test)

# %% [markdown]
# ### 3. Print some images as well as labels.

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x_train[1025 + i], cmap='gray')
    if y_train[1025 + i] == 0:
        label = 'Non-covid'
    if y_train[1025 + i] == 1:
        label = 'Covid'
    plt.title(label)
    plt.axis("off")

# for i in range(9):
#     ax = plt.subplot(3, 3, i + 1)
#     plt.imshow(x_train[1025 + i], cmap='gray')
#     if y_train[1025 + i][0] == 1:
#         label = 'Non-covid'
#     if y_train[1025 + i][1] == 1:
#         label = 'Covid'
#     plt.title(label)
#     plt.axis("off")

# %% [markdown]
# ### 4. Data augmentation.

# %%
# Check GPU
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.config.experimental.list_physical_devices('GPU')
# Out:
# Num GPUs Available:  1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# To perform convolution, add one dimension of size 1
@tf.function
def rotate(volume):
    def scipy_rotate(volume):
        # rotate the volume randomly
        angles = [-60, -45, -30, -15, 15, 30, 45, 60]
        angle = random.choice(angles)
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume
    volume_rotate = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return volume_rotate

def train_preprocessing(volume, label):
    # Rotate volume
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=2)
    return volume, label

def test_preprocessing(volume, label):
    # Only add a dimension to test data without rotation
    volume = tf.expand_dims(volume, axis=2)
    return volume, label

# %%
# Get data loaders and augmented datasets
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_loader = tf.data.Dataset.from_tensor_slices((x_test, y_test))

batch_size = 10
train_set = (train_loader.shuffle(len(x_train)).map(train_preprocessing).batch(batch_size).prefetch(2))
test_set = (test_loader.shuffle(len(x_test)).map(test_preprocessing).batch(batch_size).prefetch(2))

# %%
# Visualization after augmentation
data = train_set.take(1)
images, labels = list(data)[0]
images = images.numpy()
# print(images.shape)
labels = labels.numpy()
print("Dimension of the CT scan is:", images[0].shape)
    
def get_img(idx):
    image = images[idx]
    label = labels[idx]
    if label == 0:
        tag = 'Non-covid'
    if label == 1:
        tag = 'Covid'
    return image, tag

# def get_img(idx):
#     image = images[idx]
#     label = labels[idx]
#     if label[0] == 1:
#         tag = 'Non-covid'
#     if label[1] == 1:
#         tag = 'Covid'
#     return image, tag

plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    image, tag = get_img(i)
    plt.imshow(np.squeeze(image[:, :]), cmap="gray")
    plt.title(tag)
    plt.axis("off")
# Out:
# Dimension of the CT scan is: (256, 256, 1)

# %% [markdown]
# ### 5. Get model of NN.

# %%
def get_model(width=256, height=256):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, 1))

    x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=16, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool2D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(units=256, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Dense(units=128, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="cnn")
    return model


# Build model.
model = get_model(width=256, height=256)
model.summary()
# Out:
# Model: "cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  conv2d (Conv2D)             (None, 254, 254, 16)      160
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  batch_normalization (BatchN  (None, 127, 127, 16)     64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 16)      2320
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 16)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 62, 62, 16)       64
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 30, 30, 32)       128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 6, 6, 128)        512
#  hNormalization)
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               33024
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 166,545
# Trainable params: 166,033
# Non-trainable params: 512
# _________________________________________________________________

# %%
# Compile model.
model.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.Adam(),
    metrics=["acc"])

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    "image_2class_classification.h5", save_best_only=True)
# early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_loss", patience=20)

# Train the model
epochs = 60
model.fit(train_set, validation_data=test_set, epochs=epochs, shuffle=True, verbose=2,
    callbacks=[checkpoint_cb])
# Out:
# Epoch 1/60
# 150/150 - 12s - loss: 0.6749 - acc: 0.5860 - val_loss: 0.9392 - val_acc: 0.6040 - 12s/epoch - 81ms/step
# Epoch 2/60
# 150/150 - 8s - loss: 0.6588 - acc: 0.6267 - val_loss: 0.7277 - val_acc: 0.5600 - 8s/epoch - 57ms/step
# Epoch 3/60
# 150/150 - 9s - loss: 0.6565 - acc: 0.6280 - val_loss: 0.6417 - val_acc: 0.6700 - 9s/epoch - 59ms/step
# Epoch 4/60
# 150/150 - 9s - loss: 0.6509 - acc: 0.6320 - val_loss: 0.6118 - val_acc: 0.6760 - 9s/epoch - 58ms/step
# Epoch 5/60
# 150/150 - 9s - loss: 0.6475 - acc: 0.6400 - val_loss: 0.7201 - val_acc: 0.5320 - 9s/epoch - 58ms/step
# Epoch 6/60
# 150/150 - 9s - loss: 0.6431 - acc: 0.6467 - val_loss: 0.5954 - val_acc: 0.6840 - 9s/epoch - 57ms/step
# Epoch 7/60
# 150/150 - 9s - loss: 0.6306 - acc: 0.6513 - val_loss: 0.5889 - val_acc: 0.6880 - 9s/epoch - 59ms/step
# Epoch 8/60
# 150/150 - 8s - loss: 0.6266 - acc: 0.6600 - val_loss: 0.6297 - val_acc: 0.6800 - 8s/epoch - 57ms/step
# Epoch 9/60
# 150/150 - 9s - loss: 0.6295 - acc: 0.6673 - val_loss: 0.7841 - val_acc: 0.5320 - 9s/epoch - 59ms/step
# Epoch 10/60
# 150/150 - 9s - loss: 0.6235 - acc: 0.6600 - val_loss: 0.6269 - val_acc: 0.6560 - 9s/epoch - 58ms/step
# Epoch 11/60
# 150/150 - 9s - loss: 0.6271 - acc: 0.6507 - val_loss: 0.6422 - val_acc: 0.6100 - 9s/epoch - 57ms/step
# Epoch 12/60
# 150/150 - 8s - loss: 0.6158 - acc: 0.6747 - val_loss: 0.5977 - val_acc: 0.6940 - 8s/epoch - 56ms/step
# Epoch 13/60
# 150/150 - 9s - loss: 0.6172 - acc: 0.6813 - val_loss: 0.5723 - val_acc: 0.6880 - 9s/epoch - 59ms/step
# Epoch 14/60
# 150/150 - 9s - loss: 0.6082 - acc: 0.6707 - val_loss: 0.5951 - val_acc: 0.6800 - 9s/epoch - 59ms/step
# Epoch 15/60
# 150/150 - 9s - loss: 0.6204 - acc: 0.6627 - val_loss: 0.6689 - val_acc: 0.6280 - 9s/epoch - 58ms/step
# Epoch 16/60
# 150/150 - 9s - loss: 0.6030 - acc: 0.6707 - val_loss: 0.5720 - val_acc: 0.7180 - 9s/epoch - 57ms/step
# Epoch 17/60
# 150/150 - 9s - loss: 0.5970 - acc: 0.6760 - val_loss: 1.1728 - val_acc: 0.6040 - 9s/epoch - 58ms/step
# Epoch 18/60
# 150/150 - 9s - loss: 0.6019 - acc: 0.6833 - val_loss: 0.8168 - val_acc: 0.5800 - 9s/epoch - 57ms/step
# Epoch 19/60
# 150/150 - 9s - loss: 0.6043 - acc: 0.6907 - val_loss: 0.5671 - val_acc: 0.7020 - 9s/epoch - 58ms/step
# Epoch 20/60
# 150/150 - 8s - loss: 0.5961 - acc: 0.6767 - val_loss: 0.6512 - val_acc: 0.6440 - 8s/epoch - 56ms/step
# Epoch 21/60
# 150/150 - 9s - loss: 0.5941 - acc: 0.6907 - val_loss: 0.5751 - val_acc: 0.6880 - 9s/epoch - 57ms/step
# Epoch 22/60
# 150/150 - 8s - loss: 0.5899 - acc: 0.6967 - val_loss: 0.5950 - val_acc: 0.6720 - 8s/epoch - 57ms/step
# Epoch 23/60
# 150/150 - 9s - loss: 0.5739 - acc: 0.7020 - val_loss: 0.5844 - val_acc: 0.6800 - 9s/epoch - 58ms/step
# Epoch 24/60
# 150/150 - 9s - loss: 0.5813 - acc: 0.7033 - val_loss: 0.5749 - val_acc: 0.6980 - 9s/epoch - 58ms/step
# Epoch 25/60
# 150/150 - 9s - loss: 0.5811 - acc: 0.7013 - val_loss: 0.6305 - val_acc: 0.6340 - 9s/epoch - 58ms/step
# Epoch 26/60
# 150/150 - 9s - loss: 0.5787 - acc: 0.7073 - val_loss: 0.5573 - val_acc: 0.7340 - 9s/epoch - 57ms/step
# Epoch 27/60
# 150/150 - 9s - loss: 0.5826 - acc: 0.7027 - val_loss: 0.6053 - val_acc: 0.6620 - 9s/epoch - 58ms/step
# Epoch 28/60
# 150/150 - 9s - loss: 0.5727 - acc: 0.7173 - val_loss: 0.6398 - val_acc: 0.6800 - 9s/epoch - 58ms/step
# Epoch 29/60
# 150/150 - 9s - loss: 0.5742 - acc: 0.7093 - val_loss: 0.5628 - val_acc: 0.6880 - 9s/epoch - 58ms/step
# Epoch 30/60
# 150/150 - 9s - loss: 0.5737 - acc: 0.7120 - val_loss: 0.5499 - val_acc: 0.7100 - 9s/epoch - 57ms/step
# Epoch 31/60
# 150/150 - 9s - loss: 0.5787 - acc: 0.7107 - val_loss: 0.6002 - val_acc: 0.6740 - 9s/epoch - 58ms/step
# Epoch 32/60
# 150/150 - 9s - loss: 0.5562 - acc: 0.7280 - val_loss: 0.5432 - val_acc: 0.7140 - 9s/epoch - 58ms/step
# Epoch 33/60
# 150/150 - 9s - loss: 0.5541 - acc: 0.7173 - val_loss: 0.5295 - val_acc: 0.7360 - 9s/epoch - 59ms/step
# Epoch 34/60
# 150/150 - 9s - loss: 0.5578 - acc: 0.7253 - val_loss: 0.5579 - val_acc: 0.6960 - 9s/epoch - 58ms/step
# Epoch 35/60
# 150/150 - 9s - loss: 0.5570 - acc: 0.7280 - val_loss: 0.5607 - val_acc: 0.7240 - 9s/epoch - 57ms/step
# Epoch 36/60
# 150/150 - 9s - loss: 0.5550 - acc: 0.7213 - val_loss: 0.5860 - val_acc: 0.7040 - 9s/epoch - 57ms/step
# Epoch 37/60
# 150/150 - 9s - loss: 0.5646 - acc: 0.7233 - val_loss: 0.5291 - val_acc: 0.7340 - 9s/epoch - 58ms/step
# Epoch 38/60
# 150/150 - 9s - loss: 0.5549 - acc: 0.7193 - val_loss: 0.7134 - val_acc: 0.5960 - 9s/epoch - 59ms/step
# Epoch 39/60
# 150/150 - 9s - loss: 0.5406 - acc: 0.7407 - val_loss: 0.5376 - val_acc: 0.7340 - 9s/epoch - 59ms/step
# Epoch 40/60
# 150/150 - 9s - loss: 0.5308 - acc: 0.7487 - val_loss: 0.5403 - val_acc: 0.7300 - 9s/epoch - 58ms/step
# Epoch 41/60
# 150/150 - 9s - loss: 0.5426 - acc: 0.7367 - val_loss: 0.5872 - val_acc: 0.7120 - 9s/epoch - 59ms/step
# Epoch 42/60
# 150/150 - 9s - loss: 0.5422 - acc: 0.7400 - val_loss: 0.7019 - val_acc: 0.6520 - 9s/epoch - 58ms/step
# Epoch 43/60
# 150/150 - 9s - loss: 0.5395 - acc: 0.7267 - val_loss: 0.5915 - val_acc: 0.7020 - 9s/epoch - 57ms/step
# Epoch 44/60
# 150/150 - 9s - loss: 0.5325 - acc: 0.7407 - val_loss: 0.5850 - val_acc: 0.7400 - 9s/epoch - 57ms/step
# Epoch 45/60
# 150/150 - 9s - loss: 0.5326 - acc: 0.7400 - val_loss: 0.5962 - val_acc: 0.7100 - 9s/epoch - 58ms/step
# Epoch 46/60
# 150/150 - 9s - loss: 0.5356 - acc: 0.7380 - val_loss: 0.6060 - val_acc: 0.6940 - 9s/epoch - 58ms/step
# Epoch 47/60
# 150/150 - 9s - loss: 0.5277 - acc: 0.7527 - val_loss: 0.5200 - val_acc: 0.7580 - 9s/epoch - 58ms/step
# Epoch 48/60
# 150/150 - 9s - loss: 0.5303 - acc: 0.7447 - val_loss: 0.5738 - val_acc: 0.7100 - 9s/epoch - 57ms/step
# Epoch 49/60
# 150/150 - 9s - loss: 0.5366 - acc: 0.7400 - val_loss: 0.5613 - val_acc: 0.7360 - 9s/epoch - 58ms/step
# Epoch 50/60
# 150/150 - 9s - loss: 0.5203 - acc: 0.7447 - val_loss: 0.5516 - val_acc: 0.7180 - 9s/epoch - 58ms/step
# Epoch 51/60
# 150/150 - 9s - loss: 0.5158 - acc: 0.7507 - val_loss: 0.5430 - val_acc: 0.7240 - 9s/epoch - 57ms/step
# Epoch 52/60
# 150/150 - 9s - loss: 0.5102 - acc: 0.7547 - val_loss: 0.5409 - val_acc: 0.7340 - 9s/epoch - 58ms/step
# Epoch 53/60
# 150/150 - 8s - loss: 0.5266 - acc: 0.7540 - val_loss: 0.7221 - val_acc: 0.6480 - 8s/epoch - 56ms/step
# Epoch 54/60
# 150/150 - 9s - loss: 0.5100 - acc: 0.7567 - val_loss: 0.5855 - val_acc: 0.7060 - 9s/epoch - 57ms/step
# Epoch 55/60
# 150/150 - 9s - loss: 0.5175 - acc: 0.7527 - val_loss: 0.5620 - val_acc: 0.7340 - 9s/epoch - 57ms/step
# Epoch 56/60
# 150/150 - 9s - loss: 0.5044 - acc: 0.7520 - val_loss: 0.6402 - val_acc: 0.6920 - 9s/epoch - 57ms/step
# Epoch 57/60
# 150/150 - 9s - loss: 0.5009 - acc: 0.7727 - val_loss: 0.5688 - val_acc: 0.7100 - 9s/epoch - 58ms/step
# Epoch 58/60
# 150/150 - 9s - loss: 0.4973 - acc: 0.7573 - val_loss: 0.7530 - val_acc: 0.6760 - 9s/epoch - 57ms/step
# Epoch 59/60
# 150/150 - 9s - loss: 0.4934 - acc: 0.7713 - val_loss: 0.6047 - val_acc: 0.6740 - 9s/epoch - 57ms/step
# Epoch 60/60
# 150/150 - 8s - loss: 0.4988 - acc: 0.7647 - val_loss: 0.5713 - val_acc: 0.7000 - 8s/epoch - 57ms/step

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 10))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(model.history.history[metric])
    ax[i].plot(model.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])
plt.savefig("DLresult2.png")

# %%
max_acc_index = model.history.history['val_acc'].index(max(model.history.history['val_acc']))
print("Max Training Accuracy: ", model.history.history['acc'][max_acc_index])
print("Max Validation Accuracy: ", model.history.history['val_acc'][max_acc_index])
# Out:
# Max Training Accuracy:  0.7526666522026062
# Max Validation Accuracy:  0.7580000162124634

# %%
model.load_weights("image_2class_classification.h5")

for i in range(9):
    prediction = model.predict(np.expand_dims(x_test[125 + i], axis=0))[0]
    print('=========> result of %d image'%(i))
    if y_test[125 + i] == 0:
        print('Ground truth is: Non-covid')
    if y_test[125 + i] == 1:
        print('Ground truth is: Covid')
    if prediction < 0.5:
        print('prediction is: Non-covid')
    if prediction >= 0.5:
        print('prediction is: Covid')
# Out:
# =========> result of 0 image
# Ground truth is: Covid
# prediction is: Covid
# =========> result of 1 image
# Ground truth is: Non-covid
# prediction is: Non-covid
# =========> result of 2 image
# Ground truth is: Covid
# prediction is: Covid
# =========> result of 3 image
# Ground truth is: Non-covid
# prediction is: Covid
# =========> result of 4 image
# Ground truth is: Covid
# prediction is: Covid
# =========> result of 5 image
# Ground truth is: Non-covid
# prediction is: Non-covid
# =========> result of 6 image
# Ground truth is: Non-covid
# prediction is: Non-covid
# =========> result of 7 image
# Ground truth is: Covid
# prediction is: Covid
# =========> result of 8 image
# Ground truth is: Non-covid
# prediction is: Covid

# %%
def get_img(idx):
    image = x_test[idx]
    label = y_test[idx]
    if label == 0:
        tag = 'Non-covid'
    if label == 1:
        tag = 'Covid'
    return image, tag

plt.figure(figsize=(12, 12))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    image, tag = get_img(125 + i)
    plt.imshow(np.squeeze(image[:, :]), cmap="gray")
    prediction = model.predict(np.expand_dims(x_test[125+i], axis=0))[0]
    if prediction < 0.5:
        plt.title("Gound truth: %s \n Prediction: Non-covid" % (tag))
    if prediction >= 0.5:
        plt.title("Gound truth: %s \n Prediction: Covid" % (tag))

    plt.axis("off")
